# %% [markdown]
# <a href="https://colab.research.google.com/github/sreyanwika/PythonBasic/blob/main/PythonBasic/module3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #functions

# %%
#finding sum using functions
def sum(n1,n2,n3):
   return(n1+n2+n3)
result=sum(5,6,9)
print(result)
# Out:
# 20

# %%
#finding avg using functions
def avg(n1,n2,n3,n4):
      return(n1+n2+n3+n4)/4
rslt=avg(2,6,5,9)
print(rslt)
# Out:
# 5.5

# %%
#finding avg using functions through reading ele
s=()
a=(int(input('enter d num:')))
for i in (0,a):
        b=(int(input('enter d num:')))
        s=0+i
print(s)
def avg(s):
      return(s)/a         
rslt=avg(s)
print(rslt)
# Out:
# enter d num:3
# enter d num:1
# 0
# enter d num:2
# 3
# 1.0

# %%
#returning mltpl values
def maxmin(num):
  return(max(num),min(num))
mrks=[99,97,88,66,70]
hlmrks=maxmin(mrks)
print('the hingh{} and low is {}'.format(hlmrks[0],hlmrks[1]))
# Out:
# the hingh99 and low is 66

# %%
def maxmin(num):
  return(max(num),min(num))
mrks=[99,97,88,66,70]
hlmrks=maxmin(mrks)
print('the high and low value z',(hlmrks[0],hlmrks[1]))
# Out:
# the high and low value z (99, 66)

# %%
def maxmin(num):
  return(max(num),min(num))
mrks=[99,97,88,66,70]
h,l=maxmin(mrks)
print('the hingh{} and low is {}'.format(h,l))
# Out:
# the hingh99 and low is 66

# %%
#by using func finding younger orv elder or twins
def order(n1,n2):
  return(n1<n2)
nm1=int(input('enter d num:'))
nm2=int(input('enter d num:'))
if order(nm1,nm2):
      print('u r elder brthrr')
elif order(nm2,nm1):
      print('u r yngrr tn ur brthrr')
else:
      print('r u bth twins')
# Out:
# enter d num:45
# enter d num:34
# u r yngrr tn ur brthrr

# %%
#storing zero in the place of neg num
def change(num):
       for k in range(0,len(num)):
           if num[k]<0:
             num[k]=0
num=[11,-9,6,4,5]
print(num)
total=change(num)
print(num)
# Out:
# [11, -9, 6, 4, 5]
# [11, 0, 6, 4, 5]

# %% [markdown]
# #files

# %%
#using readline()
input=open('/fileee.txt')
emptystr=''
line=input.readline()
while line!=emptystr:
  print(line)
  line=input.readline()
input.close()
# Out:
# hyyyy
#
# presiiiii
#
# bcaaaaa
#
# stdntttttt

# %%
#writing ele in files by using write()
filee=open('/saveee','w')
filee.write('pytn mnsss snkeeee\n i get to knw abtt pytnn thizz yearrr\n intrstngg sub\n esyy to typ codee')
filee.close()

# %%
#adding ele to file
filee=open('/saveee','a')
filee.write('\nhlooo hyyyyy')
filee.close()

# %%
input=open('/saveee','r')
output=input
print(output)
input.close()
# Out:
# <_io.TextIOWrapper name='/saveee' mode='r' encoding='UTF-8'>

# %% [markdown]
# #cpy pste d files

# %%
#cpy paste the files

# %%
iff=open('/ip','r')
xy=open('/op','w')
empty_str=''
line=iff.readline()
while line!=empty_str:
  xy.write(line)
  line=iff.readline()
iff.close()
xy.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-35773b22f77d> in <module>()
# ----> 1 iff=open('/ip','r')
#       2 xy=open('/op','w')
#       3 empty_str=''
#       4 line=iff.readline()
#       5 while line!=empty_str:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/ip'

# %%
iff=open('/ip','w')
xy=open('/op','r')
empty_str=''
line=xy.readline()
while line!=empty_str:
  iff.write(line)
  line=xy.readline()
iff.close()
xy.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0b5465e2b4e7> in <module>()
#       1 iff=open('/ip','w')
# ----> 2 xy=open('/op','r')
#       3 empty_str=''
#       4 line=xy.readline()
#       5 while line!=empty_str:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/op'

# %%
f=open("/wax.txt","r")
c=f.read()
print(c)
f.close()
print("")
with open("/wax.txt","r") as f:
  print("lne1:",f.readline(),end="")
  print("lne2:",f.readline(),end="")
  print("lne3:",f.readline(),end="")
  print("lne4:",f.readline(),end="")
  print("")
with open("/wax.txt","r") as f:
  print(f.readlines())
  print("")
with open("/wax.txt","r") as f:
  for line in f:
    print("line:",line,end="")
# Out:
# hyyyyy
# nooooo
# cattttt
# camellll
#
# lne1: hyyyyy
# lne2: nooooo
# lne3: cattttt
# lne4: camellll
# ['hyyyyy\n', 'nooooo\n', 'cattttt\n', 'camellll']
#
# line: hyyyyy
# line: nooooo
# line: cattttt
# line: camellll

# %%
f=open("/wax.txt","r")
emptystr=""
line=f.readline()
while(line!=emptystr):
  print(line)
  line=f.readline()
f.close()
# Out:
# hyyyyy
#
# nooooo
#
# cattttt
#
# camellll

# %%
f=open("/wax.txt","r")
emptystr=""
line=f.read()
while(line!=emptystr):
  print(line)
  line=f.read()
f.close()
# Out:
# hyyyyy
# nooooo
# cattttt
# camellll

# %%
f=open("/wax.txt","r")
emptystr=""
line=f.readlines()
while(line!=emptystr):
  print(line,end="")
# Out:
# Streaming output truncated to the last 5000 lines.
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
with open("/wax.txt","r") as f:
  for line in f:
    f.read()
    print(line,end="")
# Out:
# hyyyyy

# %%
with open("/wax.txt","r") as f:
  line=f.readline()
for line in f:
    print(line,end="")
    f.readline()
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-020333403e1a> in <module>()
# ----> 1 with open("/wax.txt","r") as f:
#       2   line=f.readline()
#       3 for line in f:
#       4     print(line,end="")
#       5     f.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/wax.txt'
