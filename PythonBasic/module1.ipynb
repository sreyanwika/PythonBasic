# %% [markdown]
# <a href="https://colab.research.google.com/github/sreyanwika/PythonBasic/blob/main/PythonBasic/module1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(format(1/3,".3f"))
print(ord('d'))
print(chr(79))
print("hello world\n\n")
print(1,'\n',2,'\n',3)
print('\nhello world')
print('****\n***\n**\n*\n')
print(format('hey','*>10'))
print('hloio',format('hint','#^10'),'broo')
print('*\n* *\n* * *\n* * * *')
sides=4
print(type(sides))
print(id(sides))
x='awesome'
print('pythonis'+x)
x='python is'
y='awesome'
z=x+y
print(z)
x=5
y=10
print(x+y)
x=5
y='joo'
print(x+y)
# Out:
# 0.333
# 100
# O
# hello world
#
#
# 1
#  2
#  3
#
# hello world
# ****
# ***
# **
# *
#
# *******hey
# hloio ###hint### broo
# *
# * *
# * * *
# * * * *
# <class 'int'>
# 94845221235296
# pythonisawesome
# python isawesome
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-e724cccb74af> in <module>()
#      23 x=5
#      24 y='joo'
# ---> 25 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
for i in  range(5):
  print(i*i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
print(.67)
print(1.2e-200/2.4e100)
print(1/3+1/3+1/3+1/3+1/3+1/3)
pay=15
print('pay:@',pay*450)
pay=15
print('pay@',format(pay*4507.988,'.2f'))
print(format(11/12,'2e'))
# Out:
# 0.67
# 5e-301
# 1.9999999999999998
# pay:@ 6750
# pay@ 67619.82
# 9.166667e-01

# %%
print("hyrooo!")
print("jenni and takark's restaurant")
print("let's move")
# Out:
# hyrooo!
# jenni and takark's restaurant
# let's move

# %%
print(ord('v'))
print(chr(19))
print(ord("1"))
print(chr(97))
# Out:
# 118
#
# 49
# a

# %%
print("hyyy\nbyyy")
print("luv\ncrazy \nworld")
# Out:
# luv
# crazy
# world

# %%
print(format(2/3,".5f"))
print(chr(100))
print('$$$$$$$$$ * * * * *\n&&#####')
print(format('hi','@^10'))
sreya=2.4
print(id(sreya))
print(sreya)
print(sreya+2)
print(type(sreya))
print(id(sreya))
poorvi=4.3
print(id(poorvi))
x=poorvi
print(id(x))
print(x)
poorvi=poorvi+2
print(poorvi)
print(id(poorvi))
print(type(poorvi))
x,t,r='hello','hyyy','bg'
print(x,t,r)
y,n=7,6
l,d=5,8
k,s=float(y+n)/(l*d),n-float(l*d)/(d-l)*l
print('h=',k,'a=',s)
if 6<7:
       print('six less than seven')
       print('six less than seven')
g=int(input("enter num"))
b=int(input("enter num"))
print("the value of g",g)
print("the value of b",b)
if g>b:
        print("gal is tall") 
else:
      print("boy is tall")
# Out:
# 0.66667
# d
# $$$$$$$$$ * * * * *
# &&#####
# @@@@hi@@@@
# 140363849299760
# 2.4
# 4.4
# <class 'float'>
# 140363849299760
# 140363849298608
# 140363849298608
# 4.3
# 6.3
# 140363849299184
# <class 'float'>
# hello hyyy bg
# h= 0.325 a= -60.66666666666667
# six less than seven
# six less than seven
# enter num5
# enter num6
# the value of g 5
# the value of b 6
# boy is tall

# %%
v=str(input('enter num'))
print(v)
mou=int(input('enter num'))
print(mou)
tat=float(input('enter num'))
print(tat)
# Out:
# enter num3
# 3
# enter num4
# 4
# enter num5
# 5.0

# %%
x=input("enter d name:")
print(x)
# Out:
# enter d name:sreyaaa
# sreyaaa

# %%
if 3>9:
       print('three great than nine')
else:
     print('three less than nine')
# Out:
# three less than nine

# %%
import keyword
print(keyword.iskeyword('ant'))
print(keyword.iskeyword('and'))
import keyword
keyword.iskeyword('ant')
# Out:
# False
# True
# False

# %%
print(format(2/3,".5f"))
print(chr(100))
print('$$$$$$$$$ * * * * *\n&&#####')
print(format('hi','@^10'))
sreya=2.4
print(id(sreya))
print(sreya+2)
print(type(sreya))
print(id(sreya))
# Out:
# 0.66667
# d
# $$$$$$$$$ * * * * *
# &&#####
# @@@@hi@@@@
# 140363813361552
# 4.4
# <class 'float'>
# 140363813361552

# %%
print(1024)
print(0.25+10)
print(1,230)
print(0.67)
# Out:
# 1024
# 10.25
# 1 230
# 0.67

# %%
print(1.8393456e+301)
print(2.44e-320)
# Out:
# 1.8393456e+301
# 2.44e-320

# %%
print(6.25e+240*1.24e+10)
print(2.24e-240/1.45+300)
# Out:
# 7.750000000000001e+250
# 300.0

# %%
print(format(24.893952,'.3f'))
# Out:
# 24.894

# %%
print("hello")
print('hello')
print('hyy thereee')
print('')
# Out:
# hello
# hello
# hyy thereee

# %%
print(ord('1'))
print(chr(68))
print(chr(99))
# Out:
# 49
# D
# c

# %%
print('apple\nbanana\norange\npeech')
print("the unicode for'hello world' is:")
print(ord('h'),ord('e'),ord('l'),ord('l'),ord('o'))
# Out:
# apple
# banana
# orange
# peech
# the unicode for'hello world' is:
# 104 101 108 108 111

# %%
num=10
k=num
print(k)
print(id(k))
num=10
k=num+1
print(num)
print(k)
print(id(num))
print(id(k))
# Out:
# 10
# 11256352
# 10
# 11
# 11256352
# 11256384

# %%
v=(input('enter a num'))
print(v)
print("totalcsales2044=15")
print('yield==10')
# Out:
# enter a num5
# 5
# totalcsales2044=15
# yield==10

# %%
a=input('entr val of a:')
b=input('enter value of b:')
c=a+b
print(c)
# Out:
# entr val of a:5
# enter value of b:6
# 56

# %%
a=int(input('entr val of a:'))
b=int(input('enter value of b:'))
c=a+b
print(c)
# Out:
# entr val of a:5
# enter value of b:6
# 11

# %%
nme1,nme2,nme3,nme4=input('enter 4 names:').split('@')
print('nme1',nme1)
print('nme2',nme2)
print('nme3',nme3)
print('nme4',nme4)
v,n,m=4,5,6
print(v,nme1,n,nme2,m,nme3,nme4)
# Out:
# enter 4 names:raaa@vvv@ssss@mmm
# nme1 raaa
# nme2 vvv
# nme3 ssss
# nme4 mmm
# 4 raaa 5 vvv 6 ssss mmm

# %%
nme1,nme2,nme3,nme4=input('enter 4 names:').split('@')
print('nme1',nme1)
print('nme2',nme2)
print('nme3',nme3)
print('nme4',nme4)
# Out:
# enter 4 names:mm@aaa@ss@sssv
# nme1 mm
# nme2 aaa
# nme3 ss
# nme4 sssv

# %%
b,n=4,5
print(b,n)
# Out:
# 4 5

# %%
v=input('enter a string:').split('@',2)
print(v)
# Out:
# enter a string:famm@ilyy@emiii,lyyyy
# ['famm', 'ilyy', 'emiii,lyyyy']

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(10**35)
print(10==10)
print(3*33)
print(45//10)
# Out:
# 100000000000000000000000000000000000
# True
# 99
# 4

# %%
print(2+3*4)
print(2+3+4**2+1**3)
print(2+((3*4)-8))
print((2**2)**3)
print(2**(2**3))
print(4+5*45//17)
# Out:
# 14
# 22
# 6
# 64
# 256
# 17

# %%
a=9+4.5
print(a)
print('it is inclusive typweee')
v=float(4)+int(9.6)
print(v)
print('it is exclusivee typppp')
s=int(4.8)+6
print(s)
# Out:
# 13.5
# it is inclusive typweee
# 13.0
# it is exclusivee typppp
# 10

# %%
a=8
n=4
a-=n
a*=n
print(a,n)
# Out:
# 16 4

# %%
a=8
n=4
a-=n
a*=n
a+=n
a//=n
a%=n
print(a,n)
# Out:
# 1 4

# %%
num=-10
num=-num
print(num)
# Out:
# 10

# %%
a=4
b=9
print(a>b)
a=6
b=7
print(a<=b)
a=4
b=5
print(a!=b)
# Out:
# False
# True
# True

# %%
print(not 5)
print(not -1)
x,y,z=1,8,9
print(x>y and z<y)
c=-9
print(not c)
# Out:
# False
# False
# False
# False

# %%
a=11
v=[14,111,15]
print(a in v)
x='sreya'
m='buzziicccsreyallll'
print(x in m)
# Out:
# False
# True

# %%
s=123
v=1233
c=[1233,1433,13444]
print(s not in c)
print(v in c)
print(v not in c)
crazyy='nonsenseee'
print('see' in crazyy)
# Out:
# True
# True
# False
# True

# %%
import keyword
print(keyword.iskeyword('and'))
print(keyword.iskeyword('ant'))
# Out:
# True
# False

# %%
a=b=156
print(a is b)
print(id(a))
print(id(b))
a=123
v=14333
print(a is not b)
print(id(a))
print(id(v))
# Out:
# True
# 11261024
# 11261024
# True
# 11259968
# 140363813341456

# %%
c=5
v=4
sum=c+v
print('the sum of {} and {} is {}'.format(c,v,sum))
# Out:
# the sum of 5 and 4 is 9

# %%
print('i am {} ,my lngth is {}'.format('sreyaaa',198))
# Out:
# i am sreyaaa ,my lngth is 198

# %%
F=97.6
c=(F-32)*5/9
print(c)
print('the celsius value is {}'.format(c))
# Out:
# 36.44444444444444
# the celsius value is 36.44444444444444

# %%
a,b,c=2,4,6
sum=a+b+c
print(sum)
# Out:
# 12

# %%
v,s,h=3,9,4
sum=v+s+h
print(format(sum,'#^10'))
# Out:
# ####16####

# %%
maaa='veena'
paa='mouu'
x=paa
paa=maaa
print(paa)
print(x)
# Out:
# veena
# mouu

# %%
import math
a,b,c=3,4,5
s=float(a+b+c/2)
area=float(math.sqrt(s*(s-a)*(s-b)*(s-c)))
print(area)
# Out:
# 39.093637589766445

# %%
var=1
if var==1:
          print('rockyy')
# Out:
# rockyy

# %%
claus="heroo"
if claus=="zeroo":
                  print("hittt")

# %%
claus="heroo"
if claus=="heroo":
                  print("hittt")
# Out:
# hittt

# %%
vehicle=2
typp='tesla'
c='ferrori'
l='dukee'
k='ktmm'
if vehicle:
           if typp=='tesla':
                         if c=='ferrori':
                           print('the guyyy z richhh')
           if l=='dukee':
                       if k=='ktmm':
                        print('the guyy z youngggg')
# Out:
# the guyyy z richhh
# the guyy z youngggg

# %%
vehicle=2
typp='tesla'
c='ferrori'
l='dukee'
k='ktmm'
if vehicle:
           if typp=='tesla':
                         if c=='ferrori':
                           print('the guyyy z richhh')
           if l=='dukee':
                       if k=='kaira':
                        print('the guyy z youngggg')
# Out:
# the guyyy z richhh

# %%
a=11
b=15
if a<=b:
      print('galll z kindaa bigg')
else:
      print('galll z kidd')
# Out:
# galll z kindaa bigg

# %%
num1=float(input('enter a num'))
num2=float(input('enter a num'))
sum=num1+num2
print('the sum of {} and {} is {}'.format(num1,num2,sum))
print('the sum of{0} and {1} is {2}'.format(num1,num2,sum))
# Out:
# enter a num4.5
# enter a num5.8
# the sum of 4.5 and 5.8 is 10.3
# the sum of4.5 and 5.8 is 10.3

# %%
v=input('enter a value')
s=input('enter a value')
l=v
v=s
s=l
print(v,s)
# Out:
# enter a valuesweety
# enter a valuespicyy
# spicyy sweety

# %%
h=int(input('enter a num'))
if h>190:
          print('excellenttttt')
if h>180:
         print('guddd')
if h>170:
         print('avggggg')
# Out:
# enter a num185
# guddd
# avggggg

# %%
import math
a=int(input('enter a num'))
b=int(input('enter a num'))
c=int(input('enter a num'))
d=(b**2)-(4*(a*c))
rootx=float(-b+math.sqrt(d)/2*a)
rooty=float(-b-math.sqrt(d)/2*a)
print(rootx,rooty)
print('the root of{0} {1} and {2} is{3}{4}'.format(a,b,c,rootx,rooty))
# Out:
# enter a num9
# enter a num14
# enter a num4
# 18.449961479175904 -46.449961479175904
# the root of9 14 and 4 is18.449961479175904-46.449961479175904

# %%
import random
print(random.randint(0,8))
print(random.randint(0,9))
# Out:
# 2
# 9

# %%
pastry=int(input('enter avalue'))
print('binary equivalent',bin(pastry))
print('octal equivalent',oct(pastry))
print('hexa equivalent',hex(pastry))
# Out:
# enter avalue5
# binary equivalent 0b101
# octal equivalent 0o5
# hexa equivalent 0x5

# %%
i=2
while(i<6):
  print(i)
  i=i+1
  print('luv u')
# Out:
# 2
# luv u
# 3
# luv u
# 4
# luv u
# 5
# luv u

# %%
while ('telsa'):
       print('bless')
# Out:
# Streaming output truncated to the last 5000 lines.
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# bless
# ...

# %%
r=int(input('enter a value'))
area=float(3.14*(r*r))
print(area)
# Out:
# enter a value4
# 50.24

# %%
b_num = list(input("Input a binary number: "))
value = 0

for i in range(len(b_num)):
	digit = b_num.pop()
	if digit == '1':
		value = value + pow(2, i)
print("The decimal value of the number is", value)
# Out:
# Input a binary number: 1000
# The decimal value of the number is 8

# %%
def binaryToDecimal(n):
    return int(n,2)
 
 
# Driver code
if __name__ == '__main__':
    print(binaryToDecimal('100'))
    print(binaryToDecimal('101'))
    print(binaryToDecimal('1001'))
# Out:
# 4
# 5
# 9

# %%
mass=int(input('enter value '))
vel=int(input('enter value '))
print(mass,'kg')
print(vel,'m')
mom=mass*vel
print(mom)
# Out:
# enter value 4
# enter value 5
# 4 kg
# 5 m
# 20

# %%
x=int(input('enter d num'))
if x/2==0:
          print('num is even')
else:
     print('num is odd')
# Out:
# enter d num7
# num is odd

# %%
x=int(input('enter d num'))
if x>0:
       print('num is positiveee')
elif x<0:
      print('num is negativee')
else:
     print('num z zeroo')
# Out:
# enter d num0
# num z zeroo

# %%
x=int(input('enter a num'))
v=int(input('enter anum'))
y=int(input('enter anum'))
if x>v & x>y:
            print('x is grtt')
elif v>y &  v>x:
            print('v is grtt')
else:
     print('y is grtt')
# Out:
# enter a num5
# enter anum6
# enter anum7
# y is grtt

# %%
ones=int(input('enter the ones digit'))
sum=int(ones*(2**0))
tens=int(input('enter the ones digit'))
sum=int(sum+tens*(2**1))
hun=int(input('enter the ones digit'))
sum=int(sum+hun*(2**2))
thou=int(input('enter the ones digit'))
sum=int(sum+thou  *(2**3))
print('sum=',sum)
# Out:
# enter the ones digit0
# enter the ones digit1
# enter the ones digit1
# enter the ones digit1
# sum= 14

# %%
x=333
sum=int(1*(3**3))
sum=int(sum+(3**3))
sum=int(sum+(3**3))
print(sum)
# Out:
# 81

# %%
x=int(input('enter a value')
print(x)
z= x%10
v=x%100
k=x%1000
sum=int(1*(z**3))
sum=int(sum+(v**3))
sum=int(sum+(k**3))
print(sum)
# Out:
#   File "<ipython-input-71-68336f4193c9>", line 2
#     print(x)
#         ^
# SyntaxError: invalid syntax

# %%
n=int(input("enter the number"))
print(n)
a=0
i=1
while(i<=n):
          a=a+i
          i=i+1
print(a)
# Out:
# enter the number5
# 5
# 15

# %%
sum=0
for i in range(0,4):
            n=int(input('right most binary digit i '))
sum=sum+n*(2**i)
print('the dec equi is',sum)
# Out:
# right most binary digit i 0
# right most binary digit i 0
# right most binary digit i 1
# right most binary digit i 1
# the dec equi is 8

# %%
n=int(input("enter the number"))
print(n)
fact=1
for i in range(1,n+1):
                 fact=fact*i 
print(fact)
# Out:
# enter the number5
# 5
# 120

# %%
n=int(input("enter the number"))
print(n)
a=0
for i in range(1,n+1):
                     a=a+i
print(a)
# Out:
# enter the number5
# 5
# 15

# %%
sum=0
for i in (1,-5,0,7,8):
                          sum=sum+i
print(sum)
# Out:
# 11

# %%
x=int(input('enter a num'))
v=int(input('enter anum'))
y=int(input('enter anum'))
if x>v & x>y:
            print('x is grtt')
elif v>y &  v>x:
            ptint('v is grtt')
else:
            print('y is grtt')
# Out:
# enter a num4
# enter anum5
# enter anum6
# y is grtt

# %%
x=int(input('enter a value'))
print('x=',x)
z=x%10
v=x%100
k=x%1000
sum=int(1*(z**3))
sum=int(sum+(v**3))
sum=int(sum+(k**3))
print(sum)
# Out:
# enter a value500
# x= 500
# 125000000

# %%
a=input('enter a value:')
if a=='ant':
           print("apple")
elif a=='bat':
           print("bann")
else:
     print("bang")
# Out:
# enter a value:bat
# bann

# %%
value=input("enter char value:")
if value=='a':
          print("apple")
elif value=='b':
          print("banana")
else:
          print("coconut")
# Out:
# enter char value:a
# apple

# %%
v=int(input('enter marks'))
if v>=90:
         print('A')
elif v>=80:
         print('B')
elif v>=70:
        print('c')
else:
     print('F')
# Out:
# enter marks7
# F

# %%
v=int(input('enter marks'))
if v>=90:
         print('A')
elif v>=80:
         print('B')
elif v>=70:
        print('c')
else:
     print('F')
# Out:
# enter marks68
# F

# %%
l=int(input('enter the length'))
b=int(input('enter the breadth'))
p=2*(l+b)
print('p=',p)
fp=168
cfg=p*fp
print('cfg=rs.',cfg)
# Out:
# enter the length11
# enter the breadth12
# p= 46
# cfg=rs. 7728

# %%
x=input('enter name:')
y=input('enter name:')
print(x)
print(y)
xage=int(input('enter d age:'))
yage=int(input('enter d age:'))
print(xage)
print(yage)
if xage>yage:
          print(y ,'is younger')
else:
     print(x, 'is youngerrr')
# Out:
# enter name:varun
# enter name:nikhil
# varun
# nikhil
# enter d age:14
# enter d age:15
# 14
# 15
# varun is youngerrr

# %%
a=int(input('enter d side:'))
b=int(input('enter d side:'))
c=int(input('enter d side:'))
if a==b:
       print('it is isosceles')
elif a==b==c:
       print('it is equi')
else:
    print('scalene')
# Out:
# enter d side:1
# enter d side:2
# enter d side:3
# scalene

# %%
x=int(input('enter a value'))
print(x)
z= x%10
v=x%100
k=x%1000
sum=int(1*(z**3))
sum=int(sum+(v**3))
sum=int(sum+(k**3))
print(sum)
# Out:
# enter a value222
# 222
# 10951704

# %%
ch=input('enter any charac:')
if (ch>='a') & (ch<='z'):
                print("alphaaa")
elif (ch>='0' and ch<='9'):
                      print("digitt")
else:
     print("spcl charac")
# Out:
# enter any charac:7
# digitt

# %%
ch=input('enter any charac:')
if (ch>='a') & (ch<='z'):
                print("alphaaa")
elif (ch>='0') & (ch<='9'):
                      print("digitt")
else:
     print("spcl charac")
# Out:
# enter any charac:u
# alphaaa

# %%
x=int(input('enter d value:'))
y=int(input('enter d value:'))
if (x>0) &(y>0) :
               print('frstt quad')
elif (x<0) & (y>0):
                print('scnd quad')
elif (x<0)&(y<0):
                print(' trd quad')
else:
     print(' frt quad')
# Out:
# enter d value:7
# enter d value:9
# frstt quad

# %%
num1=int(input('enter d num'))
num2=int(input('enter d num'))
if num1>num2:
            print('num1 z grttt')
elif num2>num1:
            print('num2 is grtt')
else:
     print('num1 z equall to num2')
# Out:
# enter d num15
# enter d num5
# num1 z grttt

# %%
sum=0
for i in (1,-5,0,7,8):
                          sum=sum+i
print(sum)
# Out:
# 11

# %%
num1=int(input('enter d num'))
num2=int(input('enter d num'))
num3=int(input('enter d num'))
if (num1>num2)&(num1>num3):
                      print('num1 z grtttt')
elif (num2>num1)&(num2>num3):
                      print('num2 z grttttt')
else:
      print('num3 z grtttt')
# Out:
# enter d num4
# enter d num5
# enter d num3
# num2 z grttttt

# %%
n=int(input("enter the number"))
print(n)
fact=1
for i in range(1,n+1):
                 fact=fact*i 
print(fact)
# Out:
# enter the number6
# 6
# 720

# %%
ones=int(input('enter the ones digit'))
sum=int(ones*(2**0))
tens=int(input('enter the ones digit'))
sum=int(sum+tens*(2**1))
hun=int(input('enter the ones digit'))
sum=int(sum+hun*(2**2))
thou=int(input('enter the ones digit'))
sum=int(sum+thou  *(2**3))
print('sum=',sum)
if sum/5!=0:
           print('it is div by 5')
else:
     print('not divv by 5')
# Out:
# enter the ones digit0
# enter the ones digit1
# enter the ones digit0
# enter the ones digit1
# sum= 10
# it is div by 5

# %%
n=int(input('enter number:'))
a=0
b=1
c=1
for i in range(0,n+1):
    c=a+b
    a=b
    b=c
# Out:
# enter number:4

# %%
print(list(range(20,10,-2)))
# Out:
# [20, 18, 16, 14, 12]

# %%
i=6
while i<8:
        print(i)
        if i==7:
             break
        i=i+1
# Out:
# 6
# 7

# %%
#end parameter
a=int(input('enter number of digits:'))
print(5,end='')
print(4,end='')
print(6)
# Out:
# enter number of digits:3
# 546

# %%
n=int(input('enter number:'))
a=0
for i in range(1,n+1):
  a=a+1
  print(a)
# Out:
# enter number:5
# 1
# 2
# 3
# 4
# 5

# %%
n=int(input('enter number of digi:'))
x=[1,2,3,4,5]
print(x)
for i in x:
       print(i,end="")
# Out:
# enter number of digi:5
# [1, 2, 3, 4, 5]
# 12345

# %%
for y in "sreya":
     print(y)
# Out:
# s
# r
# e
# y
# a

# %%
for s in range(5,-9,-2):
         print(s)
# Out:
# 5
# 3
# 1
# -1
# -3
# -5
# -7

# %%
print('*\n* *\n* * *\n* * * *')
print('* * * *\n* * *\n* *\n*')
# Out:
# *
# * *
# * * *
# * * * *
# * * * *
# * * *
# * *
# *

# %%
n=int(input("enter value:"))
if n==n**3:
           print("armstrongg num")
elif (n>99)&(x<999):
            l=n%10
            n=int(n/10)
            b=n%10
            n=int(n/10)
            v=(a**3+b**3+n**3)
            n==v
            print('armstrngg num')
else:
            print('invalidd optnn')
# Out:
# enter value:0
# armstrongg num

# %%
n=int(input('enter number:'))
a=0
b=1
c=a+b
for i in range(1,n+1):
         a=b
         b=c
         c=a+b
         print(a)
# Out:
# enter number:5
# 1
# 1
# 2
# 3
# 5

# %%
n=int(input('enter number of digi:'))
b1=int(input("num:"))
b2=int(input("num:"))
b3=int(input("num:"))
b4=int(input("num:"))
digits=b1,b2,b3,b4
print('digits:',digits)
for i in digits:
          print(i,end="")
# Out:
# enter number of digi:4
# num:1
# num:2
# num:3
# num:4
# digits: (1, 2, 3, 4)
# 1234

# %%
n=int(input('enter number of digi:'))
x=[1,2,3,4,5]
print(x)
for i in x:
       print(i,end="")
# Out:
# enter number of digi:5
# [1, 2, 3, 4, 5]
# 12345

# %%
n=int(input('enter number:'))
a=0
b=1
c=a+b
d=0
for i in range(1,n+1):
         a=b
         b=c
         c=a+b
         d=+i
         print(a)
# Out:
# enter number:1
# 1

# %%
"""heuuuu
jlooooo
jjjjj"""
print("hello")
# Out:
# hello

# %%
print("hloo,nn")
print(1,'\n',2,'\n',3,'\n',4)
# Out:
# hloo,nn
# 1
#  2
#  3
#  4

# %%
x=str('34')
print(type(x))
# Out:
# <class 'str'>

# %%
b=input('enter nme:').split(',',2)
print(b)
# Out:
# enter nme:sretya,naa,maaa,kaa,mmm,
# ['sretya', 'naa', 'maaa,kaa,mmm,']

# %%
print(2*3//4)
print(2+3*4)
print(2*3/4)
# Out:
# 1
# 14
# 1.5

# %%
x={'a':'apple','b':'batt','c':'catt'}
for l in x:
  print(x[l])
  print(l)
# Out:
# apple
# a
# batt
# b
# catt
# c

# %%
import math
r=6
a=math.pi*(6**2)
print(a)
# Out:
# 113.09733552923255

# %%
def show_excitement():
  name=[]
  for i in range(5):
    a=input('input:')
    name.append(a)
  return(name)
show_excitement()
# Out:
# ['I am super excited for this course!',
#  'I am super excited for this course!',
#  'I am super excited for this course!',
#  'I am super excited for this course!',
#  'I am super excited for this course!']

# %%
def show_excitement(name):
    # Your code goes here!
    a=name * 5
    return(a)
          

show_excitement("I am super excited for this course! ")
# Out:
# 'I am super excited for this course! I am super excited for this course! I am super excited for this course! I am super excited for this course! I am super excited for this course! '

# %%
def show_excitement():
    # Your code goes here!
    a="poorvi "
    print(a *5)
    return()
show_excitement()
# Out:
# poorvi poorvi poorvi poorvi poorvi
# ()

# %%
def show_excitement():
    # Your code goes here!
    a="I am super excited for this course! "
    return(a*5)
show_excitement()
# Out:
# 'I am super excited for this course! I am super excited for this course! I am super excited for this course! I am super excited for this course! I am super excited for this course! '
